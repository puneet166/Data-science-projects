# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from apyori import apriori
from matplotlib.pylab import rcParams
rcParams['figure.figsize']=10,6

# %%
data=pd.read_csv('accident_ind.csv')
data
# Out:
#      Unnamed: 0            Data   Countries     Local Industry_Sector  \
# 0             0   1/1/2016 0:00  Country_01  Local_01          Mining
# 1             1   1/2/2016 0:00  Country_02  Local_02          Mining
# 2             2   1/6/2016 0:00  Country_01  Local_03          Mining
# 3             3   1/8/2016 0:00  Country_01  Local_04          Mining
# 4             4  1/10/2016 0:00  Country_01  Local_04          Mining
# 5             5  1/12/2016 0:00  Country_02  Local_05          Metals
# 6             6  1/16/2016 0:00  Country_02  Local_05          Metals
# 7             7  1/17/2016 0:00  Country_01  Local_04          Mining
# 8             8  1/19/2016 0:00  Country_02  Local_02          Mining
# 9             9  1/26/2016 0:00  Country_01  Local_06          Metals
# 10           10  1/28/2016 0:00  Country_01  Local_03          Mining
# 11           11  1/30/2016 0:00  Country_01  Local_03          Mining
# ...

# %%
data['Data']=pd.to_datetime(data['Data'],infer_datetime_format=True)

data.set_index('Data')['Accident_type'].resample('W').count().plot()
plt.show()
print(type(data['Data']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-cb46b592a4d1> in <module>
#       1 data['Data']=pd.to_datetime(data['Data'],infer_datetime_format=True)
#       2
# ----> 3 data['Accident_type'].resample('W').count().plot()
#       4 plt.show()
#       5 print(type(data['Data']))
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in resample(self, rule, how, axis, fill_method, closed, label, convention, kind, loffset, limit, base, on, level)
#    8153                      axis=axis, kind=kind, loffset=loffset,
#    8154                      convention=convention,
# -> 8155                      base=base, key=on, level=level)
#    8156         return _maybe_process_deprecations(r,
#    8157                                            how=how,
#
# ~\Anaconda3\lib\site-packages\pandas\core\resample.py in resample(obj, kind, **kwds)
#    1248     """
# ...

# %%
from datetime import datetime
data2=data[['Data','Accident_type']]
data2['Data']=pd.to_datetime(data2['Data'],infer_datetime_format=True)
indexedDataset=data2.set_index(['Data'])
print(indexedDataset)
# Out:
#             Accident_type
# Data
# 2016-01-01              1
# 2016-01-02              1
# 2016-01-06              1
# 2016-01-08              1
# 2016-01-10              4
# 2016-01-12              1
# 2016-01-16              1
# 2016-01-17              1
# 2016-01-19              1
# 2016-01-26              1
# 2016-01-28              1
# 2016-01-30              1
# 2016-02-01              1
# 2016-02-02              4
# 2016-02-04              1
# 2016-02-04              1
# 2016-02-06              3
# 2016-02-07              1
# 2016-02-08              1
# 2016-02-21              1
# 2016-02-25              1
# 2016-02-09              1
# 2016-02-10              2
# 2016-02-15              2
# 2016-02-14              1
# 2016-02-15              1
# 2016-02-13              1
# 2016-02-15              1
# 2016-02-16              1
# 2016-02-16              2
# ...                   ...
# 2017-05-19              1
# 2017-05-23              1
# 2017-05-23              1
# ...

# %%
indexedDataset.plot()

# %%
data2.dtypes
# Out:
# Data             datetime64[ns]
# Accident_type             int64
# dtype: object

# %%
data2['Accident_type'].astype(str).astype(int)

plt.plot(indexedDataset)
# Out:
# C:\Users\Puneet Singh\Anaconda3\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Data'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-73ec88202984> in <module>
# ...
