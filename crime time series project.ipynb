# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv('crime.csv',engine='python',parse_dates=["YEAR"])

data.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP   OFFENSE_DESCRIPTION  \
# 0      I182070945           619               Larceny    LARCENY ALL OTHERS
# 1      I182070943          1402             Vandalism             VANDALISM
# 2      I182070941          3410                 Towed   TOWED MOTOR VEHICLE
# 3      I182070940          3114  Investigate Property  INVESTIGATE PROPERTY
# 4      I182070938          3114  Investigate Property  INVESTIGATE PROPERTY
#
#   DISTRICT REPORTING_AREA SHOOTING     OCCURRED_ON_DATE       YEAR  MONTH  \
# 0      D14            808      NaN  2018-09-02 13:00:00 2018-01-01      9
# 1      C11            347      NaN  2018-08-21 00:00:00 2018-01-01      8
# 2       D4            151      NaN  2018-09-03 19:27:00 2018-01-01      9
# 3       D4            272      NaN  2018-09-03 21:16:00 2018-01-01      9
# 4       B3            421      NaN  2018-09-03 21:05:00 2018-01-01      9
#
# ...

# %%
print(type(data['YEAR']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
data.tail()
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE OFFENSE_CODE_GROUP  \
# 319068   I050310906-00          3125    Warrant Arrests
# 319069   I030217815-08           111           Homicide
# 319070   I030217815-08          3125    Warrant Arrests
# 319071   I010370257-00          3125    Warrant Arrests
# 319072       142052550          3125    Warrant Arrests
#
#                         OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 319068                       WARRANT ARREST       D4            285      NaN
# 319069  MURDER, NON-NEGLIGIENT MANSLAUGHTER      E18            520      NaN
# 319070                       WARRANT ARREST      E18            520      NaN
# 319071                       WARRANT ARREST      E13            569      NaN
# 319072                       WARRANT ARREST       D4            903      NaN
#
#            OCCURRED_ON_DATE       YEAR  MONTH DAY_OF_WEEK  HOUR    UCR_PART  \
# 319068  2016-06-05 17:25:00 2016-01-01      6      Sunday    17  Part Three
# ...

# %%
data4=data.groupby(['MONTH']).count()
data4
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  OFFENSE_DESCRIPTION  \
# MONTH
# 1                23610         23610               23610                23610
# 2                21653         21653               21653                21653
# 3                24146         24146               24146                24146
# 4                24086         24086               24086                24086
# 5                26199         26199               26199                26199
# 6                30568         30568               30568                30568
# 7                34556         34556               34556                34556
# 8                34823         34823               34823                34823
# 9                26543         26543               26543                26543
# 10               25737         25737               25737                25737
# 11               23675         23675               23675                23675
# ...

# %%
plt.rcParams["figure.figsize"] = [15,150]

da=data['OFFENSE_DESCRIPTION'].value_counts().plot(kind='barh');
da.set_title('frequency distribution of offense')
da.set_xlabel('offense')
da.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
print(type(data['OCCURRED_ON_DATE']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
data2=data.groupby(['YEAR']).count()
data2
# Out:
#             INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# YEAR
# 2015-01-01            53388         53388               53388
# 2016-01-01            99114         99114               99114
# 2017-01-01           100886        100886              100886
# 2018-01-01            65685         65685               65685
#
#             OFFENSE_DESCRIPTION  DISTRICT  REPORTING_AREA  SHOOTING  \
# YEAR
# 2015-01-01                53388     53260           53388       185
# 2016-01-01                99114     98597           99114       279
# 2017-01-01               100886    100310          100886       370
# 2018-01-01                65685     65141           65685       185
#
#             OCCURRED_ON_DATE   MONTH  DAY_OF_WEEK    HOUR  UCR_PART  STREET  \
# YEAR
# 2015-01-01             53388   53388        53388   53388     53387   52106
# 2016-01-01             99114   99114        99114   99114     99080   93399
# ...

# %%
data3=data2[['OFFENSE_DESCRIPTION']]
data3
# Out:
#             OFFENSE_DESCRIPTION
# YEAR
# 2015-01-01                53388
# 2016-01-01                99114
# 2017-01-01               100886
# 2018-01-01                65685

# %%
  
# new data frame with split value columns 
new = data["OCCURRED_ON_DATE"].str.split(" ", n = 0, expand = True) 
  
# making separate first genric column from new data frame 
data["DATE"]= new[0] 
  
# making separate second genric column from new data frame 
# making separate third genric column from new data frame 


# Dropping old Name columns 
#data.drop(columns =["date_added"], inplace = True) 
  
# df display 
#data.isnull().sum()

# %%
data.head(10)
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE               OFFENSE_CODE_GROUP  \
# 0      I182070945           619                          Larceny
# 1      I182070943          1402                        Vandalism
# 2      I182070941          3410                            Towed
# 3      I182070940          3114             Investigate Property
# 4      I182070938          3114             Investigate Property
# 5      I182070936          3820  Motor Vehicle Accident Response
# 6      I182070933           724                       Auto Theft
# 7      I182070932          3301                  Verbal Disputes
# 8      I182070931           301                          Robbery
# 9      I182070929          3301                  Verbal Disputes
#
#                           OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA  \
# 0                          LARCENY ALL OTHERS      D14            808
# 1                                   VANDALISM      C11            347
# ...

# %%
data['DATE']=pd.to_datetime(data['DATE'],infer_datetime_format=True)

# %%
print(type(data['DATE']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
plt.rcParams["figure.figsize"] = [15,500]

data4=data[['DATE','OFFENSE_DESCRIPTION']]
data4.groupby(['DATE']).count().plot(kind='barh')

# %%
plt.rcParams["figure.figsize"] = [15,15]

data5=data[['DAY_OF_WEEK','OFFENSE_DESCRIPTION']]
data5.groupby(['DAY_OF_WEEK']).count().plot(kind='bar')

# %%
from datetime import datetime

data5=data[['DATE','OFFENSE_DESCRIPTION']]

print(type(data5['DATE']))
data5['DATE']=pd.to_datetime(data5['DATE'])
data5=data5.groupby(['DATE']).count()
data5
#print(type(data5['DATE']))
# Out:
# <class 'pandas.core.series.Series'>
# C:\Users\Puneet Singh\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#             OFFENSE_DESCRIPTION
# DATE
# 2015-06-15                  249
# 2015-06-16                  249
# 2015-06-17                  234
# 2015-06-18                  294
# 2015-06-19                  289
# 2015-06-20                  261
# 2015-06-21                  186
# 2015-06-22                  262
# 2015-06-23                  266
# 2015-06-24                  276
# 2015-06-25                  294
# 2015-06-26                  273
# 2015-06-27                  310
# 2015-06-28                  237
# 2015-06-29                  252
# 2015-06-30                  259
# ...

# %%
data5.plot(grid=True)

# %%
Startdate=datetime(2017,1,1)
enddate=datetime(2018,1,1)
data5[(Startdate<=data5.index)&(enddate>=data5.index)].plot(grid=True)

# %%
Startdate=datetime(2017,1,1)
enddate=datetime(2017,2,1)
data5[(Startdate<=data5.index)&(enddate>=data5.index)].plot(grid=True)

# %%
Startdate=datetime(2017,1,1)
enddate=datetime(2017,1,2)
data5[(Startdate<=data5.index)&(enddate>=data5.index)].plot(grid=True)
